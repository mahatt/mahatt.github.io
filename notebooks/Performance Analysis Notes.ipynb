# %% [markdown]
# ## Performance Analysis for CPU
# #### Microbenchmarks
# #### Roofline model
# * https://en.wikipedia.org/wiki/Roofline_model
# ![image.png](attachment:image.png)
#
# ## Arch Book
# ### ILP
# ![image-2.png](attachment:image-2.png)
# #### Data Dependences and Hazards
# ![image-3.png](attachment:image-3.png)
# * data dependence
# ![image-4.png](attachment:image-4.png)
# * antidependence between instruction i and instruction j occurs when instruction j writes a register or memory location that instruction i reads.
#     + x1
#     + Register renaming
# ![image-5.png](attachment:image-5.png)
# *  output dependence : instruction i and instruction j write the same register or memory location.
#     + Register renaming
#
# * Data Hazards
#     + RAW
#     + WAW
#     + WAR
#
# * ILP
#     + Unroll
#     + Branch Predication
#
# * Dynamic Scheduling Using Tomasulo’s Approach
#     + RAW - Execute Operands when available
#     + WAR - Rename register
#     + WAW - Rename Registers
#             + Rename all destination registers including peding read/write from prev instructions
#             + Concept of reservation station
#
#  ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ### PERF BOOK
# #### CPU Microarchitecture
# * Pipeline
# ![image.png](attachment:image.png)
#
# * Modern CPU Design
# ![image-2.png](attachment:image-2.png)
#
#
#
#  + Frontend
#      - Uops not delivered? https://easyperf.net/blog/2018/12/29/Understanding-IDQ_UOPS_NOT_DELIVERED
#      - Port Contension ? https://easyperf.net/blog/2018/03/21/port-contention

# %% [markdown]
# ### References
#
# * [Performance Analysis on a Modern CPU](https://easyperf.net/)

# %% [markdown]
# ## Tools
# * Static Scheduling Trace
#     + LLVM-MCA
#         - does not model frontend
#     + ICAC
#     + upos.info *  uica https://uica.uops.info/
#         - detailed pipeline model
